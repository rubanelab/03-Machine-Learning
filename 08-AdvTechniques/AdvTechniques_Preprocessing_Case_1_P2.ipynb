# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("/content/50_startups.csv")

dataset = pd.get_dummies(dataset, drop_first=True)

X = dataset[['R&D Spend', 'Administration', 'Marketing Spend', 'State_Florida', 'State_New York']]
y = dataset["Profit"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
raw_input = [1300, 12000, 4000, 0, 1]
raw_input
# Out:
# [1300, 12000, 4000, 0, 1]

# %%
scaled_input = scaler.transform([raw_input])
scaled_input
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.46755405, -4.33835385, -1.50744257, -0.5       ,  1.30088727]])

# %%
import pickle
filename = "finalized_model_adv.sav"

loaded_model = pickle.load(open(filename, "rb"))

# %%
result = loaded_model.predict([[42, 22.4, 2, 0, 0]])
print("Result for pre-processed input (X-var) only:", result)
# Out:
# Result for pre-processed input (X-var) only: [108599.21691873]
